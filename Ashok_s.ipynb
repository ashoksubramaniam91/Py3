# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Df1=pd.read_csv('C:\\Users\\Ashok\\Downloads\\Data+set+-+EDA.csv')

# %%
Df1
# Out:
#          Rank Grade                      Channel name Video Uploads  \
# 0         1st  A++                             Zee TV         82757
# 1         2nd  A++                           T-Series         12661
# 2         3rd  A++         Cocomelon - Nursery Rhymes           373
# 3         4th  A++                          SET India         27323
# 4         5th  A++                                WWE         36756
# 5         6th  A++                         Movieclips         30243
# 6         7th  A++                         netd müzik          8500
# 7         8th  A++              ABS-CBN Entertainment        100147
# 8         9th  A++                    Ryan ToysReview          1140
# 9        10th  A++                        Zee Marathi         74607
# 10       11th   A+                    5-Minute Crafts          2085
# 11       12th   A+                    Canal KondZilla           822
# 12       13th   A+                   Like Nastya Vlog           150
# ...

# %%
Df1.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views'],
#       dtype='object')

# %%
Df1.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
Df1.tail()
# Out:
#          Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4995  4,996th   B+      Uras Benlioğlu           706     2072942    441202795
# 4996  4,997th   B+   HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4,998th   B+         Mastersaint           110     3265735    311758426
# 4998  4,999th   B+      Bruce McIntosh          3475       32990     14563764
# 4999  5,000th   B+           SehatAQUA           254       21172     73312511

# %%
Df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
# Rank             5000 non-null object
# Grade            5000 non-null object
# Channel name     5000 non-null object
# Video Uploads    5000 non-null object
# Subscribers      5000 non-null object
# Video views      5000 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %%
Df1.describe()
# Out:
#         Video views
# count  5.000000e+03
# mean   1.071449e+09
# std    2.003844e+09
# min    7.500000e+01
# 25%    1.862329e+08
# 50%    4.820548e+08
# 75%    1.124368e+09
# max    4.754884e+10

# %%
Df1.shape
# Out:
# (5000, 6)

# %%
Df1.nunique #it will show how many unique values are there
# Out:
# <bound method DataFrame.nunique of          Rank Grade                      Channel name Video Uploads  \
# 0         1st  A++                             Zee TV         82757
# 1         2nd  A++                           T-Series         12661
# 2         3rd  A++         Cocomelon - Nursery Rhymes           373
# 3         4th  A++                          SET India         27323
# 4         5th  A++                                WWE         36756
# 5         6th  A++                         Movieclips         30243
# 6         7th  A++                         netd müzik          8500
# 7         8th  A++              ABS-CBN Entertainment        100147
# 8         9th  A++                    Ryan ToysReview          1140
# 9        10th  A++                        Zee Marathi         74607
# 10       11th   A+                    5-Minute Crafts          2085
# 11       12th   A+                    Canal KondZilla           822
# ...

# %%
Df1.isnull().sum()
# Out:
# Rank             0
# Grade            0
# Channel name     0
# Video Uploads    0
# Subscribers      0
# Video views      0
# dtype: int64

# %%
#1)What are the top 10 youtube channels as ordered by ‘number of subcribers’?

# %%
D1=Df1.sort_values(by='Subscribers',ascending=0)

# %%
D1.head(10)
# Out:
#          Rank Grade                         Channel name Video Uploads  \
# 1002  1,003rd    A                               BIGBANG           769
# 75       76th    A         Doggy Doggy Play Doh Cartoons           909
# 306     307th    A                             DrakeVEVO            38
# 4898  4,899th                               ExzoticSlice            --
# 1336  1,337th   A-   HooplaKidz Franҫais - Comptines et…           358
# 704     705th    A                        MrSuicideSheep          2077
# 4872  4,873rd   B+                   Dutch Lady Việt Nam           219
# 4356  4,357th   B+                   자동차 & 로봇 장난감 Car &…          3077
# 3740  3,741st   B+                          westlifeVEVO           273
# 2728  2,729th   B+                         Pablo Oficial           178
#
#      Subscribers  Video views
# 1002     9998464   4756874954
# 75       9994112   3155585139
# 306      9987454   4908039128
# 4898       99785      9745292
# 1336      997671    240365487
# ...

# %%
#########

# %%
Df1['Video Uploads']=Df1['Video Uploads'].replace('--',np.nan)

# %%
Df1.dropna(inplace=True)

# %%
Df1['Video Uploads']=Df1['Video Uploads'].astype('int')

# %%
Df1['Subscribers']=Df1['Subscribers'].replace('-- ',np.nan)

# %%
Df1['Subscribers']=Df1['Subscribers'].astype(float)

# %%
Df1['Video Uploads'].dropna()
# Out:
# 0        82757
# 1        12661
# 2          373
# 3        27323
# 4        36756
# 5        30243
# 6         8500
# 7       100147
# 8         1140
# 9        74607
# 10        2085
# 11         822
# 12         150
# 13          50
# 14       16119
# 15       49239
# 16        4778
# 17          53
# 18        3060
# 19       24287
# 20          48
# 21        3403
# 22       19358
# 23        1833
# 24      186194
# 25        5076
# 26         277
# 27         555
# 28       92250
# 29         230
#          ...
# 4970     13547
# 4971      1206
# 4972      2071
# 4973       202
# 4974       153
# 4975         1
# 4976       297
# 4977      2184
# 4978        49
# 4979       707
# 4980       878
# 4981         5
# 4982      9876
# 4983       242
# 4984      2116
# 4985       191
# 4986      7299
# 4987      1358
# 4988        80
# 4989       219
# 4990       208
# 4991        11
# 4992        25
# 4993      1055
# 4994      1735
# 4995       706
# 4996       797
# ...

# %%
Df1.describe()
# Out:
#        Video Uploads   Subscribers   Video views
# count    4994.000000  4.610000e+03  4.994000e+03
# mean     3859.463556  2.621527e+06  1.072618e+09
# std     17085.866498  3.927263e+06  2.004762e+09
# min         1.000000  3.010000e+02  7.500000e+01
# 25%       141.000000  6.101925e+05  1.863155e+08
# 50%       443.000000  1.350884e+06  4.824501e+08
# 75%      1501.750000  2.950921e+06  1.124961e+09
# max    422326.000000  6.599531e+07  4.754884e+10

# %%
Df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4994 entries, 0 to 4999
# Data columns (total 6 columns):
# Rank             4994 non-null object
# Grade            4994 non-null object
# Channel name     4994 non-null object
# Video Uploads    4994 non-null int32
# Subscribers      4610 non-null float64
# Video views      4994 non-null int64
# dtypes: float64(1), int32(1), int64(1), object(3)
# memory usage: 253.6+ KB

# %%
#2)Generate a table which only contains data for channels which have less than 5000 video uploads. Sort this table by Rank.

# %%
D2=Df1[Df1['Video Uploads']<5000]

# %%
D2['Rank']=D2['Video Uploads'].rank(ascending=1,method='dense')
# Out:
# C:\Users\Ashok\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
D2.sort_values(by='Video Uploads')
# Out:
#         Rank Grade                       Channel name  Video Uploads  \
# 1328     1.0   A-                            Sunny TV              1
# 2404     1.0   B+                  ItsHARSH007 Gaming              1
# 4474     1.0   B+                           hyghhopes              1
# 4975     1.0   B+                          Funny Kids              1
# 628      1.0    A                          cocoz toon              1
# 4100     1.0   B+                     DenzelCurryVEVO              1
# 3909     2.0   B+                  Afife Semra DURMUŞ              2
# 2572     2.0   B+                           Calphalon              2
# 1259     2.0   A-                          Toy School              2
# 4432     2.0   B+     Bublik Nursery rhymes Kids show              2
# 3889     2.0   B+                           DDN FILMS              2
# 2265     2.0   B+                                TV宝宝              2
# 4946     2.0   B+                          AitanaVEVO              2
# ...

# %%
#4)Plot the distribution of video views for the top 500 channels.

# %%
D3=Df1.sort_values('Video views',ascending=0)

# %%
D4=D3.head(500)

# %%
D4
# Out:
#          Rank Grade                         Channel name  Video Uploads  \
# 1         2nd  A++                              T-Series          12661
# 4         5th  A++                                   WWE          36756
# 8         9th  A++                       Ryan ToysReview           1140
# 6         7th  A++                            netd müzik           8500
# 3         4th  A++                             SET India          27323
# 0         1st  A++                                Zee TV          82757
# 11       12th   A+                       Canal KondZilla            822
# 1470  1,471st   A-                             PewDiePie           3601
# 435     436th    A                      JustinBieberVEVO            123
# 271     272nd    A   Little Baby Bum - Nursery Rhymes &…            680
# 81       82nd    A                            Get Movies           2747
# 7         8th  A++                 ABS-CBN Entertainment         100147
# ...

# %%
sns.distplot(D4['Video views'])
# Out:
# C:\Users\Ashok\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#############

# %%
Df1.isnull().sum()
# Out:
# Rank               0
# Grade              0
# Channel name       0
# Video Uploads      0
# Subscribers      384
# Video views        0
# dtype: int64

# %%
Df1['Subscribers']=Df1['Subscribers'].replace(np.nan,Df1['Subscribers'].median())

# %%
Df1.isnull().sum()
# Out:
# Rank             0
# Grade            0
# Channel name     0
# Video Uploads    0
# Subscribers      0
# Video views      0
# dtype: int64

# %%
Df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4994 entries, 0 to 4999
# Data columns (total 6 columns):
# Rank             4994 non-null object
# Grade            4994 non-null object
# Channel name     4994 non-null object
# Video Uploads    4994 non-null int32
# Subscribers      4994 non-null float64
# Video views      4994 non-null int64
# dtypes: float64(1), int32(1), int64(1), object(3)
# memory usage: 253.6+ KB

# %%
#3)Is there a relation ship between the number of video uploads and the number of subscribers? Generate a plot to support your answer.

# %%
plt.scatter(Df1["Video Uploads"],Df1["Subscribers"])
plt.title("Video Uploads Vs Subscribers ")
plt.ylabel("Subscribers")
plt.xlabel("Video Uploads")
# Out:
# Text(0.5, 0, 'Video Uploads')

# %%
#6)Create correlation matrix for the datasets and  plot the pairwise correlations.

# %%
corrmat = Df1.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
sns.set()
cols = ['Video views', 'Subscribers', 'Video Uploads']
sns.pairplot(Df1[cols], size = 2.5)
plt.show();
# Out:
# C:\Users\Ashok\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
#5)

# %%
Df1['Grade']=Df1['Grade'].astype(str)

# %%
D5=Df1.groupby(['Grade']).count()

# %%
D5
# Out:
#        Rank  Channel name  Video Uploads  Subscribers  Video views
# Grade
# A       963           963            963          963          963
# A+       41            41             41           41           41
# A++      10            10             10           10           10
# A-     1024          1024           1024         1024         1024
# B+     2956          2956           2956         2956         2956

# %%
#Which grade has the highest number of channels?

# %%
D5.index.max()
# Out:
# 'B+ '

# %%
#Plot a gradewise distribution of all the youtube channels.

# %%
plt.bar(D5.index,D5['Channel name'])
plt.show()

# %%
#9)Are there any outliers in the data. Generate boxplots to support your answer.

# %%
#Yes there are many outliers in subscribers, video upload and video views solumns

# %%
sns.boxplot(x=Df1['Subscribers'],data=Df1)

# %%
sns.boxplot(x=Df1['Video views'],data=Df1)

# %%
sns.boxplot(x=Df1['Video Uploads'],data=Df1)

# %%
#7)Create a new column in the dataset which contains the average number of subcribers per video upload. What are the top 5 channels based on this calculated average?

# %%
Df1['Avg_Subscribers']=Df1['Subscribers']/Df1['Video Uploads']

# %%
Df1.sort_values(by='Avg_Subscribers',ascending=0)
Df1.head(5)
# Out:
#   Rank Grade                Channel name  Video Uploads  Subscribers  \
# 0  1st   A++                      Zee TV          82757   18752951.0
# 1  2nd   A++                    T-Series          12661   61196302.0
# 2  3rd   A++  Cocomelon - Nursery Rhymes            373   19238251.0
# 3  4th   A++                   SET India          27323   31180559.0
# 4  5th   A++                         WWE          36756   32852346.0
#
#    Video views  Avg_Subscribers
# 0  20869786591       226.602596
# 1  47548839843      4833.449333
# 2   9793305082     51577.080429
# 3  22675948293      1141.183582
# 4  26273668433       893.795462

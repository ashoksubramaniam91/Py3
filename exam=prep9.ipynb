# %%
Which of the following is the incorrect way to define series?
#none of these

Series is a onedimensional labeled array capable of holding any data type.
#True

Which of the following object you get after reading CSV file?
#DataFrame

How to find out the number of observations and columns in dataset?
#shape

Point out the wrong statement:
#Data visualization is the organization of information according to preset specifications

What is the function of hue?
#Variables that define subsets of the data

We Can pass values for both `x` and `y’ in countplot.
#Statement is False

Which of the following statements are correct for in seaborn?
1. x and y are numerical data
2. x and y are categorical data
3. hue, row, column(col) should be categorical data
4. hue, row, column(col) should be numerical data
#1,2

Which of the following statements is correct when code is executed?
Dframe_name=dropna(how=’all’)
#It will drop all null values in row.

What is the use of inplace=True?
#It will make changes in original dataframe.

Which of the following thing can be data in Pandas ?
#all of the Mentioned

Which of the following statements are correct for loc and iloc?
a. .iloc is predefined
index and .loc is a userdefined
index.
b. .iloc is userdefined
index and .loc is a predefined
index.
c. .loc takes slices based on labels and .iloc uses observations position
d. .loc uses observations position and .iloc takes slices based on labels
#c,b

Which of the following input can be accepted by DataFrame ?
#All of the Mentioned

In Index([u'USSR', u'Germany', u'China', u'Japan', u'USA'], dtype='object')
What does 'u' stand for?
#unique

Which of the function from pandas read the data set from a large text file?
#read_csv

Which function in Pandas library allows to play with data and creates new variables?
#Apply function

Which of the following Python libraries provides support for data manipulation ?
#Pandas

Which of the following is the output of the below Python code?
import numpy as np
series = [[23,45,12,679], [14,48,69,38]]
new_series = np.array(series)
print new_series.ndim
print new_series.shape
print new_series.dtype
#2 (2L, 4L) int32

What is the output of the below Python code?
import numpy as np
percentiles = [98, 76.37, 55.55, 69, 88]
first_subject = np.array(percentiles)
print first_subject.dtype
#float64

What is seaborn?
#statistical data visualization

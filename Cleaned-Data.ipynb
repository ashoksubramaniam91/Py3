# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
Df1=pd.read_csv('C:\\Users\\Ashok\\Desktop\\EDA\\Data+set+-+EDA.csv')

# %%
Df1.drop('Rank',axis=1,inplace=True)

# %%
Df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 5 columns):
# Grade            5000 non-null object
# Channel name     5000 non-null object
# Video Uploads    5000 non-null object
# Subscribers      5000 non-null object
# Video views      5000 non-null int64
# dtypes: int64(1), object(4)
# memory usage: 195.4+ KB

# %%
#Df1['Grade']=Df1['Grade'].str.replace('[^A-Za-z0-9]+','')
Df1['Channel name']=Df1['Channel name'].str.replace('[^A-Za-z0-9]+','')
Df1['Video Uploads']=Df1['Video Uploads'].str.replace('[^A-Za-z0-9]+','')
Df1['Subscribers']=Df1['Subscribers'].str.replace('[^A-Za-z0-9]+','')
Df1['Video views']=Df1['Video views'].replace('[^A-Za-z0-9]+','')

# %%
Df1.isnull().sum()
# Out:
# Grade            0
# Channel name     0
# Video Uploads    0
# Subscribers      0
# Video views      0
# dtype: int64

# %%
Df1['Grade']=Df1['Grade'].replace('',np.nan)
Df1['Channel name']=Df1['Channel name'].replace('',np.nan)
Df1['Video Uploads']=Df1['Video Uploads'].replace('',np.nan)
Df1['Subscribers']=Df1['Subscribers'].replace('',np.nan)
Df1['Video views']=Df1['Video views'].replace('',np.nan)

# %%
Df1.isnull().sum()
# Out:
# Grade              0
# Channel name     271
# Video Uploads      6
# Subscribers      387
# Video views        0
# dtype: int64

# %%
Df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 5 columns):
# Grade            5000 non-null object
# Channel name     4729 non-null object
# Video Uploads    4994 non-null object
# Subscribers      4613 non-null object
# Video views      5000 non-null int64
# dtypes: int64(1), object(4)
# memory usage: 195.4+ KB

# %%
Df1['Video Uploads']=Df1['Video Uploads'].astype(float)
Df1['Subscribers']=Df1['Subscribers'].astype(float)
Df1['Video views']=Df1['Video views'].astype(float)

# %%
Df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 5 columns):
# Grade            5000 non-null object
# Channel name     4729 non-null object
# Video Uploads    4994 non-null float64
# Subscribers      4613 non-null float64
# Video views      5000 non-null float64
# dtypes: float64(3), object(2)
# memory usage: 195.4+ KB

# %%
Df1.isnull().sum()
# Out:
# Grade              0
# Channel name     271
# Video Uploads      6
# Subscribers      387
# Video views        0
# dtype: int64

# %%
Df1['Video Uploads']=Df1['Video Uploads'].replace(np.nan,Df1['Video Uploads'].median())
Df1['Subscribers']=Df1['Subscribers'].replace(np.nan,Df1['Subscribers'].median())
Df1['Video views']=Df1['Video views'].replace(np.nan,Df1['Video views'].median())
Df1['Channel name']=Df1['Channel name'].replace(np.nan,'Data Missing')

# %%
Df1.isnull().sum()
# Out:
# Grade            0
# Channel name     0
# Video Uploads    0
# Subscribers      0
# Video views      0
# dtype: int64

# %%
Df1.describe()
# Out:
#        Video Uploads   Subscribers   Video views
# count    5000.000000  5.000000e+03  5.000000e+03
# mean     3855.363800  2.521743e+06  1.071449e+09
# std     17076.019571  3.786633e+06  2.003844e+09
# min         1.000000  3.010000e+02  7.500000e+01
# 25%       141.000000  6.668025e+05  1.862329e+08
# 50%       443.000000  1.350477e+06  4.820548e+08
# 75%      1500.250000  2.723182e+06  1.124368e+09
# max    422326.000000  6.599531e+07  4.754884e+10

# %%
Df1.nunique()
# Out:
# Grade               6
# Channel name     4693
# Video Uploads    2285
# Subscribers      4611
# Video views      5000
# dtype: int64

# %%
D2=Df1[Df1['Video Uploads']<5000]

# %%
D2
# Out:
#      Grade                 Channel name  Video Uploads  Subscribers  \
# 2     A++        CocomelonNurseryRhymes          373.0   19238251.0
# 8     A++                RyanToysReview         1140.0   16082927.0
# 10     A+                 5MinuteCrafts         2085.0   33492951.0
# 11     A+                CanalKondZilla          822.0   39409726.0
# 12     A+                LikeNastyaVlog          150.0    7662886.0
# 13     A+                         Ozuna           50.0   18824912.0
# 16     A+               WORLDSTARHIPHOP         4778.0   15830098.0
# 17     A+                 VladandNikita           53.0    1350477.0
# 18     A+                       Badabun         3060.0   23603062.0
# 20     A+                  xxxtentacion           48.0   11593509.0
# 21     A+               ZeeMusicCompany         3403.0   23440427.0
# 23     A+                     DeadloxMC         1833.0    2137907.0
# 26     A+                       ibighit          277.0   16924523.0
# ...

# %%
Df1.groupby(['Grade']).count()
# Out:
#        Channel name  Video Uploads  Subscribers  Video views
# Grade
# A               963            963          963          963
# A+               41             41           41           41
# A++              10             10           10           10
# A-             1024           1024         1024         1024
# B+             2956           2956         2956         2956
#                   6              6            6            6

# %%
D=Df1[Df1['Subscribers']>5000]

# %%
D.sort_values(by='Subscribers')
# Out:
#      Grade                Channel name  Video Uploads  Subscribers  \
# 4183   B+                BonafontLevit           13.0       5318.0
# 3437   B+              igrovieavtomati           26.0       5614.0
# 4600   B+   FabelleExquisiteChocolates           73.0       6069.0
# 3780   B+               KaliUchisTopic           46.0       6076.0
# 4199   B+                 PTNutriSains           85.0       6106.0
# 3864   B+                 KumhoTireUSA           72.0       6198.0
# 2470   B+              PolycrolPiramal           26.0       6427.0
# 3123   B+     mondaycomformerlydapulse           86.0       6461.0
# 4533   B+        TmallAliExpressRussia           41.0       7143.0
# 4214   B+                 Data Missing          162.0       7549.0
# 4100   B+              DenzelCurryVEVO            1.0       8012.0
# 3190   B+              XMENVitNamnngch           50.0       8193.0
# 4672   B+                 KLN50667NEWS          382.0       8858.0
# ...

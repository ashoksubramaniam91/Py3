# %%
In hypothesis testing, the hypothesis which is tentatively assumed to be true is called the
#Null hypothesis 

Shop Floor Manager in Dairy Company feels that the Milk Packaging Process unit for 1 Litre Packs is
working fine and does not need any calibration. SD = 10 ml. What is the Null
Hypothesis?
#Null Hypothesis : µ = 1

A Manager wants to know if his team spends less than 9 hours a day in office. The null
hypothesis for this example will be that the population mean is:
#Greater than or equal to 9 hours 

A manufacturer’s Quality Control department rejects a lot when it has actually met the
market acceptable quality level. This is Producer’s Risk
#This is Type l Error 

In hypothesis testing, the rejection region for testing H0 is µ ≥ 150 ; HA is µ < 150 at the 10% level of
significance is:
#Z > 1.96 

Which of the following is not an example of Poisson distribution?
#You draw a card from a deck. It is Ace. What is the probability of the second card being an Ace

A coin is tossed three consecutive times, what is the probability of getting at least two
consecutive head?
#3/8

A drilling company has estimated a 40% chance of striking oil for their new well. A detailed test has been
scheduled for more information. Historically, 60% of successful wells have had detailed tests, and 20% of
unsuccessful wells have had detailed tests. Given that this well has been scheduled for a detailed test,
what is the the probability that the well be successful?
#2/3

If median < mean, then the distribution is said to be
#Right­Skewed

Which of the following is not an example of a discrete probability distribution?
#The price of a house 

Median of 40, 16, 68, 35, 20, 87, 54, 26 is
#47 

A pharmaceutical company wants to diagnose the effect of a new drug in reducing blood levels sugar for a sample of 20 people selected at random in a hospital. Which of the following test will be appropriate for this study?
# Paired t test 

Pick the appropriate level of significance to avoid type 1 error in decision making.
# .001 

Which of the following test can be used to address the question of whether the sports preference (Tennis and Cricket) is independent of gender of the person?
#Chi Square test 

A driver was travelling 50 kmph for the first one third of the distance and then 60 kmph for the remaining distance. What is the average speed of the travel?
#56.25 kmph 

In a normal distribution, what is the percent of the data that lies in the bell shaped distribution within 3 standard deviations of mean?
# 99.7% 

Two events A and B are independent if,
#P(A ∩ B) = P(A).P(B) 

A company has been advertising its products in a television and found that 64% of the people who watched their advertisements bought their products and 78% of the people who did not watch, did not buy the products. If the 25% of people watched the advertisement, what is the probability that a randomly selected person will not watch the advertisement and do not buy the product?
#51/80 

A test is called a two tailed test when H0 is
#µ = µ0 

What is the main difference between binomial and poisson distributions?
#Poisson deals with the number of defects and binomial deals with defective analysis

Find out the best batsman using the following details.
Batsman Mean Score Standard Deviation
1         90        35
2         60        24
3        105        50
4         85        27
#Batsman 4 

A normal distribution becomes standard normal with
#Mean = 0, SD = 1 

What is the possible hypothesis test outcome when we do not reject H0 when it is false?
#Type 2 error 

Distribution of aircrafts landing each hour in an airport is an example of
#Poisson 

Which of the following is true for mutually exclusive events?
#  AꓴB = Φ 
  P(AꓵB) = 1 
  P(AꓴB) = P(A) + P(B) – P(AꓵB) 
Correct!
  #None of these 
    
A researcher in charge of the new software evaluation project hopes to show that the new software package will provide a shorter mean project completion time. Thus, the researcher is looking for evidence to conclude that µ2 is efficient than µ1.
State whether the following null hypothesis can be used for this testing.
H0 : µ1 - µ2 > 0
# No 

One way anova has
#One dependent and one independent variable 

The p value is best defined as
#The probability of observing the data or more extreme values if the null hypothesis is true

A measurement scale that has no arbitrary or absolute zero is called
#Interval Scale

In the complete randomized design, the variance between columns measures the difference between
#Sample mean of the group and population mean 

What is the confidence level of a hypothesis test when significance level is =0.1 ?
#90% 

Test statistic used in Anova is
#F-Test 

Which of the following is a dimension reduction technique?
#Principal Component Analysis 

Completely Randomised Design has
#One factor or one independent variable 

A manufacturer of soft drinks states that it fills one-litre container of its products with an average of atleast 33.8 fluid ounces. To test the claim, a sample of one-litre containers have been selected at random and the contents were measured.
State the null hypothesis H0 to test manufacturer’s claim:
#µ>=33.8 

If four unbiased coins are tossed, what is the probability of getting atmost 2 heads?
#9/16 

Which of the following sentences is true about supervised and unsupervised learning?
#  Unsupervised learning does not use prior information about the data 

Which of the following is not affected by extreme values?
#Median

A bag contains 25% of balls in red, 55% in yellow and 20% in blue. If 3 balls are picked one by one at random without replacement and the remaining balls in the bag is 85% , find out the probability of picking a blue ball in the second when the first ball was red?
#4/19

The graph showing the paired points of (xi, yi) is called:
#Scatter plot

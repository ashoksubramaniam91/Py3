# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\Ashok\\Desktop\\Data.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
df.corr()
# Out:
#                           Unnamed: 0        ID       Age   Overall  Potential  \
# Unnamed: 0                  1.000000  0.415757 -0.454846 -0.972791  -0.633395
# ID                          0.415757  1.000000 -0.739208 -0.417025   0.047074
# Age                        -0.454846 -0.739208  1.000000  0.452350  -0.253312
# Overall                    -0.972791 -0.417025  0.452350  1.000000   0.660939
# Potential                  -0.633395  0.047074 -0.253312  0.660939   1.000000
# Special                    -0.596508 -0.231352  0.236695  0.606960   0.383727
# International Reputation   -0.413322 -0.356191  0.253765  0.499491   0.372993
# Weak Foot                  -0.204026 -0.075784  0.059867  0.212015   0.162346
# Skill Moves                -0.415672 -0.056914  0.027649  0.414463   0.354290
# Jersey Number               0.213645  0.182074 -0.241156 -0.218931  -0.010474
# Crossing                   -0.390062 -0.131994  0.130545  0.394972   0.246319
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                      0
# ID                              0
# Name                            0
# Age                             0
# Photo                           0
# Nationality                     0
# Flag                            0
# Overall                         0
# Potential                       0
# Club                          241
# Club Logo                       0
# Value                           0
# Wage                            0
# Special                         0
# Preferred Foot                 48
# International Reputation       48
# Weak Foot                      48
# Skill Moves                    48
# Work Rate                      48
# Body Type                      48
# Real Face                      48
# Position                       60
# Jersey Number                  60
# Joined                       1553
# Loaned From                 16943
# Contract Valid Until          289
# Height                         48
# ...

# %%
df
# Out:
#        Unnamed: 0      ID                  Name  Age  \
# 0               0  158023              L. Messi   31
# 1               1   20801     Cristiano Ronaldo   33
# 2               2  190871             Neymar Jr   26
# 3               3  193080                De Gea   27
# 4               4  192985          K. De Bruyne   27
# 5               5  183277             E. Hazard   27
# 6               6  177003             L. Modrić   32
# 7               7  176580             L. Suárez   31
# 8               8  155862          Sergio Ramos   32
# 9               9  200389              J. Oblak   25
# 10             10  188545        R. Lewandowski   29
# 11             11  182521              T. Kroos   28
# 12             12  182493              D. Godín   32
# 13             13  168542           David Silva   32
# 14             14  215914              N. Kanté   27
# 15             15  211110             P. Dybala   24
# 16             16  202126               H. Kane   24
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
# Unnamed: 0                  18207 non-null int64
# ID                          18207 non-null int64
# Name                        18207 non-null object
# Age                         18207 non-null int64
# Photo                       18207 non-null object
# Nationality                 18207 non-null object
# Flag                        18207 non-null object
# Overall                     18207 non-null int64
# Potential                   18207 non-null int64
# Club                        17966 non-null object
# Club Logo                   18207 non-null object
# Value                       18207 non-null object
# Wage                        18207 non-null object
# Special                     18207 non-null int64
# Preferred Foot              18159 non-null object
# International Reputation    18159 non-null float64
# Weak Foot                   18159 non-null float64
# ...

# %%
del df['Unnamed: 0']

# %%
df['Release Clause']=df['Release Clause'].str.replace('€','')

# %%
def value_to_float(x):
    if type(x) == float or type(x) == int:
        return x
    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
    if 'M' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
    if 'B' in x:
        return float(x.replace('B', '')) * 1000000000
    return x

# %%
df['Release Clause']=df['Release Clause'].apply(value_to_float).astype(float)

# %%
df
# Out:
#            ID                  Name  Age  \
# 0      158023              L. Messi   31
# 1       20801     Cristiano Ronaldo   33
# 2      190871             Neymar Jr   26
# 3      193080                De Gea   27
# 4      192985          K. De Bruyne   27
# 5      183277             E. Hazard   27
# 6      177003             L. Modrić   32
# 7      176580             L. Suárez   31
# 8      155862          Sergio Ramos   32
# 9      200389              J. Oblak   25
# 10     188545        R. Lewandowski   29
# 11     182521              T. Kroos   28
# 12     182493              D. Godín   32
# 13     168542           David Silva   32
# 14     215914              N. Kanté   27
# 15     211110             P. Dybala   24
# 16     202126               H. Kane   24
# 17     194765          A. Griezmann   27
# 18     192448         M. ter Stegen   26
# 19     192119           T. Courtois   26
# 20     189511       Sergio Busquets   29
# 21     179813             E. Cavani   31
# ...

# %%
df.isnull().sum()
# Out:
# ID                              0
# Name                            0
# Age                             0
# Photo                           0
# Nationality                     0
# Flag                            0
# Overall                         0
# Potential                       0
# Club                          241
# Club Logo                       0
# Value                           0
# Wage                            0
# Special                         0
# Preferred Foot                 48
# International Reputation       48
# Weak Foot                      48
# Skill Moves                    48
# Work Rate                      48
# Body Type                      48
# Real Face                      48
# Position                       60
# Jersey Number                  60
# Joined                       1553
# Loaned From                 16943
# Contract Valid Until          289
# Height                         48
# Weight                         48
# ...

# %%
df['Release Clause']=df['Release Clause'].replace(np.nan,df['Release Clause'].median())

# %%
df['Loaned From']=df['Loaned From'].replace(np.nan,'Data Not Available')

# %%
df['GKReflexes']=df['GKReflexes'].replace(np.nan,df['GKReflexes'].median())

# %%
df['GKPositioning']=df['GKPositioning'].replace(np.nan,df['GKPositioning'].median())

# %%
df['GKKicking']=df['GKKicking'].replace(np.nan,df['GKKicking'].median())

# %%
df['GKHandling']=df['GKHandling'].replace(np.nan,df['GKHandling'].median())

# %%
df['GKDiving']=df['GKDiving'].replace(np.nan,df['GKDiving'].median())

# %%
df['SlidingTackle']=df['SlidingTackle'].replace(np.nan,df['SlidingTackle'].median())

# %%
df['StandingTackle']=df['StandingTackle'].replace(np.nan,df['StandingTackle'].median())

# %%
df['Marking']=df['Marking'].replace(np.nan,df['Marking'].median())

# %%
df['Composure']=df['Composure'].replace(np.nan,df['Composure'].median())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 88 columns):
# ID                          18207 non-null int64
# Name                        18207 non-null object
# Age                         18207 non-null int64
# Photo                       18207 non-null object
# Nationality                 18207 non-null object
# Flag                        18207 non-null object
# Overall                     18207 non-null int64
# Potential                   18207 non-null int64
# Club                        17966 non-null object
# Club Logo                   18207 non-null object
# Value                       18207 non-null object
# Wage                        18207 non-null object
# Special                     18207 non-null int64
# Preferred Foot              18159 non-null object
# International Reputation    18159 non-null float64
# Weak Foot                   18159 non-null float64
# Skill Moves                 18159 non-null float64
# ...

# %%
df['Penalties']=df['Penalties'].replace(np.nan,df['Penalties'].median())

# %%
df['Vision']=df['Vision'].replace(np.nan,df['Vision'].median())

# %%
df['Positioning']=df['Positioning'].replace(np.nan,df['Positioning'].median())

# %%
df['Interceptions']=df['Interceptions'].replace(np.nan,df['Interceptions'].median())

# %%
df['Aggression']=df['Aggression'].replace(np.nan,df['Aggression'].median())

# %%
df['LongShots']=df['LongShots'].replace(np.nan,df['LongShots'].median())

# %%
df['Strength']=df['Strength'].replace(np.nan,df['Strength'].median())

# %%
df['Stamina']=df['Stamina'].replace(np.nan,df['Stamina'].median())

# %%
df['Jumping']=df['Jumping'].replace(np.nan,df['Jumping'].median())

# %%
df['ShotPower']=df['ShotPower'].replace(np.nan,df['ShotPower'].median())

# %%
df['Balance']=df['Balance'].replace(np.nan,df['Balance'].median())

# %%
df['Reactions']=df['Reactions'].replace(np.nan,df['Reactions'].median())

# %%
df['Agility']=df['Agility'].replace(np.nan,df['Agility'].median())

# %%
df['SprintSpeed']=df['SprintSpeed'].replace(np.nan,df['SprintSpeed'].median())

# %%
df['Acceleration']=df['Acceleration'].replace(np.nan,df['Acceleration'].median())

# %%
df['BallControl']=df['BallControl'].replace(np.nan,df['BallControl'].median())

# %%
df['LongPassing']=df['LongPassing'].replace(np.nan,df['LongPassing'].median())

# %%
df['FKAccuracy']=df['FKAccuracy'].replace(np.nan,df['FKAccuracy'].median())

# %%
df['Curve']=df['Curve'].replace(np.nan,df['Curve'].median())

# %%
df['Dribbling']=df['Dribbling'].replace(np.nan,df['Dribbling'].median())

# %%
df['Volleys']=df['Volleys'].replace(np.nan,df['Volleys'].median())

# %%
df['ShortPassing']=df['ShortPassing'].replace(np.nan,df['ShortPassing'].median())

# %%
df['HeadingAccuracy']=df['HeadingAccuracy'].replace(np.nan,df['HeadingAccuracy'].median())

# %%
df['Finishing']=df['Finishing'].replace(np.nan,df['Finishing'].median())

# %%
df['Crossing']=df['Crossing'].replace(np.nan,df['Crossing'].median())

# %%
df.drop(['Photo','Club Logo','Flag'],axis=1,inplace=True)

# %%
df
# Out:
#            ID                  Name  Age          Nationality  Overall  \
# 0      158023              L. Messi   31            Argentina       94
# 1       20801     Cristiano Ronaldo   33             Portugal       94
# 2      190871             Neymar Jr   26               Brazil       92
# 3      193080                De Gea   27                Spain       91
# 4      192985          K. De Bruyne   27              Belgium       91
# 5      183277             E. Hazard   27              Belgium       91
# 6      177003             L. Modrić   32              Croatia       91
# 7      176580             L. Suárez   31              Uruguay       91
# 8      155862          Sergio Ramos   32                Spain       91
# 9      200389              J. Oblak   25             Slovenia       90
# 10     188545        R. Lewandowski   29               Poland       90
# 11     182521              T. Kroos   28              Germany       90
# ...

# %%
df['Value']=df['Value'].str.replace('€','')
df['Wage']=df['Wage'].str.replace('€','')

# %%
df['Value']=df['Value'].apply(value_to_float).astype(float)
df['Wage']=df['Wage'].apply(value_to_float).astype(float)

# %%
df
# Out:
#            ID                  Name  Age          Nationality  Overall  \
# 0      158023              L. Messi   31            Argentina       94
# 1       20801     Cristiano Ronaldo   33             Portugal       94
# 2      190871             Neymar Jr   26               Brazil       92
# 3      193080                De Gea   27                Spain       91
# 4      192985          K. De Bruyne   27              Belgium       91
# 5      183277             E. Hazard   27              Belgium       91
# 6      177003             L. Modrić   32              Croatia       91
# 7      176580             L. Suárez   31              Uruguay       91
# 8      155862          Sergio Ramos   32                Spain       91
# 9      200389              J. Oblak   25             Slovenia       90
# 10     188545        R. Lewandowski   29               Poland       90
# 11     182521              T. Kroos   28              Germany       90
# ...

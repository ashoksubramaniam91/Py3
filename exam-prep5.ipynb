# %%
1)Which of the following statements is true with respect to mutability in Python?
Bytearray is mutable

2)Which of these functions reverses the objects of a list in place?
list.reverse()

3)To retrieve the character ‘r’ from string strng=”Sherlock”, which of the following commands can we execute from the following list ?
strng.__getitem__(3)

4)numbers = (1, 2, 3, 4)
result = map(lambda x: x + x, numbers)
print(list(result))
What would be the output of the above code snippet?
2,4,6,8

5)Which of these are possible operations that can be performed using reduce function in Python?
All of the above


6)'&*$#&*()abc123'.isalnum()
On executing the above code, the output will be FALSE, in order to get the output to TRUE,
How should you modify the input ?
All of the above

7)# python code to demonstrate working of reduce()
 # importing functools for reduce()
import functools
 # initializing list
lis = [ 1 , 3, 5, 6, 2, ]
print (functools.reduce(lambda a,b : a+b,lis))
With respect to the above code snippet, choose the most appropriate answer:?
Reduce is a built in function which is used to reduce the values in a collection to a single item

8)Which of the following methods creates an object which can be iterated one element at a time?
iter()

9)Answer the question with respect to the code snippet in the below example
 # Return double of n
def addition(n):
    return n + n
 # We double all numbers using map()
numbers = (1, 2, 3, 4)
result = map(addition, numbers)
print(list(result))
Execute the above code and try to choose the correct answer.?
The code runs correctly because the map is a built in function in Python

10)Which of the following statement is invalid in Python?
[‘a’,’b’,’c’].length()

11)Iterators can be set on which of the following data types in Python
All of the above

12)Choose the correct the answer with respect to the below code:
def myf(x, L=[]):
  L.append(x)
  print(L)
myf(10)
myf(20)
On executing the above code snippet, the output would contain both 10 and 20, in case if I do not want this to happen, what can be fixed in the code?
L=none in the function arguments

13)for i in [1, 71, 13, 2, 81, 15]:
 print(i, end=' ')
 if (i%2) == 0:
   break
What will be the output of the above code?
1 71 13 2

14)Which of the following statements in Python will throw an error when executed?
Perth’ [6]

15)While working with dictionaries like the one in the below example
Color_codes = {"red" : "rot", "green" : "grün", "blue" : "blau", "yellow":"gelb"}
print(Color_code["blau"])
What will be the output?
Syntax error



'
